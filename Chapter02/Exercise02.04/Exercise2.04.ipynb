# %% [markdown]
# ### Exercise 2.04 : Detect Entities in a Set of Documents

# %% [markdown]
# ### Pre checkup
# Assuming boto3 is installed _pip install boto3_
#
# Assuming a configuration is done by _aws configure_
#
# * Configured as follows in .aws/config:
#  * [default]
#  * _output = json_
#  * _region = us-west-2_
# * Configured as follows in .aws/credentials:
#  * [default]
#  * _aws_access_key_id = YOUR_ACCESS_KEY_
#  * _aws_secret_access_key = YOUR_SECRET_KEY_

# %%
# import the AWS SDK for python (boto3) - http://boto3.readthedocs.io/en/latest/
import boto3
# import json module to serialize JSON - https://docs.python.org/3.6/library/json.html
import json
# import glob to find text files with .txt ending - https://docs.python.org/3.6/library/glob.html
import glob
# import os to obtain current working directory - https://docs.python.org/3.6/library/os.html
import os

# %%
# instantiate a new comprehend client
comprehend = boto3.client(service_name='comprehend')

data_dir = '../reviews__pos/*.txt' 
# Works for Linux, OSX. Change to \\ for windows. 
#print(data_dir)
file_list = glob.glob(data_dir)
#print(file_list)

for file in file_list:
    with open(file, 'r', encoding="utf-8") as f:
        file_as_str = f.read()
        # python string formatting to print the text file name
        print('Calling detect_entities_from_documents.py on file: %s' % file[-15:])
        # json.dumps() writes JSON data to a Python string
        print(json.dumps(comprehend.detect_entities(Text = file_as_str, LanguageCode='en'), sort_keys=True, indent=4))
        print('End of detect_entities\n')
# Out:
# Calling detect_entities_from_documents.py on file: cv471_16858.txt
# {
#     "Entities": [
#         {
#             "BeginOffset": 27,
#             "EndOffset": 32,
#             "Score": 0.8627497553825378,
#             "Text": "1500s",
#             "Type": "DATE"
#         },
#         {
#             "BeginOffset": 35,
#             "EndOffset": 42,
#             "Score": 0.6783493757247925,
#             "Text": "england",
#             "Type": "LOCATION"
#         },
#         {
#             "BeginOffset": 45,
#             "EndOffset": 54,
#             "Score": 0.9995773434638977,
#             "Text": "elizabeth",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 173,
#             "EndOffset": 181,
#             "Score": 0.7939422726631165,
#             "Text": "catholic",
#             "Type": "OTHER"
#         },
#         {
#             "BeginOffset": 312,
#             "EndOffset": 322,
#             "Score": 0.8026664853096008,
#             "Text": "protestant",
#             "Type": "ORGANIZATION"
#         },
#         {
#             "BeginOffset": 360,
#             "EndOffset": 368,
#             "Score": 0.8968406319618225,
#             "Text": "catholic",
#             "Type": "OTHER"
#         },
#         {
#             "BeginOffset": 394,
#             "EndOffset": 403,
#             "Score": 0.9997500777244568,
#             "Text": "elizabeth",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 509,
#             "EndOffset": 518,
#             "Score": 0.7206460237503052,
#             "Text": "catholics",
#             "Type": "ORGANIZATION"
#         },
#         {
#             "BeginOffset": 523,
#             "EndOffset": 534,
#             "Score": 0.8726661205291748,
#             "Text": "protestants",
#             "Type": "ORGANIZATION"
#         },
#         {
#             "BeginOffset": 562,
#             "EndOffset": 571,
#             "Score": 0.9995794892311096,
#             "Text": "elizabeth",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 575,
#             "EndOffset": 584,
#             "Score": 0.9998611211776733,
#             "Text": "elizabeth",
#             "Type": "PERSON"
#         }
#     ],
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "1097",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Tue, 31 Mar 2020 01:01:14 GMT",
#             "x-amzn-requestid": "46d7784c-1454-49c1-b2a8-637c84d19a65"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "46d7784c-1454-49c1-b2a8-637c84d19a65",
#         "RetryAttempts": 0
#     }
# }
# End of detect_entities
#
# Calling detect_entities_from_documents.py on file: cv114_18398.txt
# {
#     "Entities": [
#         {
#             "BeginOffset": 328,
#             "EndOffset": 339,
#             "Score": 0.7320008873939514,
#             "Text": "one brother",
#             "Type": "QUANTITY"
#         },
#         {
#             "BeginOffset": 852,
#             "EndOffset": 869,
#             "Score": 0.9731943011283875,
#             "Text": "michelle pfeiffer",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 961,
#             "EndOffset": 978,
#             "Score": 0.8031756281852722,
#             "Text": "a thousand acres'",
#             "Type": "QUANTITY"
#         },
#         {
#             "BeginOffset": 985,
#             "EndOffset": 988,
#             "Score": 0.7384347319602966,
#             "Text": "one",
#             "Type": "QUANTITY"
#         },
#         {
#             "BeginOffset": 1169,
#             "EndOffset": 1183,
#             "Score": 0.9993646144866943,
#             "Text": "whoopi golberg",
#             "Type": "PERSON"
#         }
#     ],
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "529",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Tue, 31 Mar 2020 01:01:15 GMT",
#             "x-amzn-requestid": "79bec6bd-e237-4776-9de2-cc23a5936d52"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "79bec6bd-e237-4776-9de2-cc23a5936d52",
#         "RetryAttempts": 0
#     }
# }
# End of detect_entities
