# %% [markdown]
# ### Exercise 2.04 : Detect Entities in a Set of Documents

# %% [markdown]
# ### Pre checkup
# Assuming boto3 is installed _pip install boto3_
#
# Assuming a configuration is done by _aws configure_
#
# * Configured as follows in .aws/config:
#  * [default]
#  * _output = json_
#  * _region = us-west-2_
# * Configured as follows in .aws/credentials:
#  * [default]
#  * _aws_access_key_id = YOUR_ACCESS_KEY_
#  * _aws_secret_access_key = YOUR_SECRET_KEY_

# %%
# import the AWS SDK for python (boto3) - http://boto3.readthedocs.io/en/latest/
import boto3
# import json module to serialize JSON - https://docs.python.org/3.6/library/json.html
import json
# import glob to find text files with .txt ending - https://docs.python.org/3.6/library/glob.html
import glob
# import os to obtain current working directory - https://docs.python.org/3.6/library/os.html
import os

# %%
# instantiate a new comprehend client
comprehend = boto3.client(service_name='comprehend')


data_dir = os.getcwd() + '/reviews__pos/*.txt' 
# Works for Linux, OSX. Need \ for windows. Need to make this OS agnostic
#print(data_dir)
file_list = glob.glob(data_dir)
#print(file_list)

for file in file_list:
    with open(file, 'r', encoding="utf-8") as f:
        file_as_str = f.read()
        # python string formating to print the text file name
        print('Calling detect_entities_from_documents.py on file: %s' % file[-15:])
        # json.dumps() writes JSON data to a Python string
        print(json.dumps(comprehend.detect_entities(Text = file_as_str, LanguageCode='en'), sort_keys=True, indent=4))
        print('End of detect_entities\n')
# Out:
# Calling detect_entities_from_documents.py on file: cv471_16858.txt
# {
#     "Entities": [
#         {
#             "BeginOffset": 27,
#             "EndOffset": 32,
#             "Score": 0.9988731741905212,
#             "Text": "1500s",
#             "Type": "DATE"
#         },
#         {
#             "BeginOffset": 35,
#             "EndOffset": 42,
#             "Score": 0.9942895174026489,
#             "Text": "england",
#             "Type": "LOCATION"
#         },
#         {
#             "BeginOffset": 45,
#             "EndOffset": 54,
#             "Score": 0.9999986886978149,
#             "Text": "elizabeth",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 173,
#             "EndOffset": 181,
#             "Score": 0.6192143559455872,
#             "Text": "catholic",
#             "Type": "ORGANIZATION"
#         },
#         {
#             "BeginOffset": 360,
#             "EndOffset": 368,
#             "Score": 0.4906325340270996,
#             "Text": "catholic",
#             "Type": "ORGANIZATION"
#         },
#         {
#             "BeginOffset": 394,
#             "EndOffset": 403,
#             "Score": 0.9999994039535522,
#             "Text": "elizabeth",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 408,
#             "EndOffset": 423,
#             "Score": 0.8387759923934937,
#             "Text": "cate blanchette",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 465,
#             "EndOffset": 470,
#             "Score": 0.9887890219688416,
#             "Text": "queen",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 471,
#             "EndOffset": 475,
#             "Score": 0.5043115019798279,
#             "Text": "mary",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 562,
#             "EndOffset": 571,
#             "Score": 0.9999998807907104,
#             "Text": "elizabeth",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 575,
#             "EndOffset": 584,
#             "Score": 0.9999990463256836,
#             "Text": "elizabeth",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 658,
#             "EndOffset": 672,
#             "Score": 0.8736693859100342,
#             "Text": "joseph fiennes",
#             "Type": "PERSON"
#         }
#     ],
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "1190",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Sat, 18 Jan 2020 04:27:54 GMT",
#             "x-amzn-requestid": "591d5cf2-3698-462e-ba9c-c5a2ca450e10"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "591d5cf2-3698-462e-ba9c-c5a2ca450e10",
#         "RetryAttempts": 0
#     }
# }
# End of detect_entities
#
# Calling detect_entities_from_documents.py on file: cv114_18398.txt
# {
#     "Entities": [
#         {
#             "BeginOffset": 328,
#             "EndOffset": 331,
#             "Score": 0.9513667821884155,
#             "Text": "one",
#             "Type": "QUANTITY"
#         },
#         {
#             "BeginOffset": 840,
#             "EndOffset": 848,
#             "Score": 0.9615708589553833,
#             "Text": "a second",
#             "Type": "QUANTITY"
#         },
#         {
#             "BeginOffset": 852,
#             "EndOffset": 869,
#             "Score": 0.7110430598258972,
#             "Text": "michelle pfeiffer",
#             "Type": "PERSON"
#         },
#         {
#             "BeginOffset": 961,
#             "EndOffset": 978,
#             "Score": 0.9998134970664978,
#             "Text": "a thousand acres'",
#             "Type": "QUANTITY"
#         },
#         {
#             "BeginOffset": 985,
#             "EndOffset": 997,
#             "Score": 0.8666272163391113,
#             "Text": "one fine day",
#             "Type": "QUANTITY"
#         },
#         {
#             "BeginOffset": 1169,
#             "EndOffset": 1183,
#             "Score": 0.9962085485458374,
#             "Text": "whoopi golberg",
#             "Type": "PERSON"
#         }
#     ],
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "629",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Sat, 18 Jan 2020 04:27:54 GMT",
#             "x-amzn-requestid": "bb082953-2c91-4649-abc2-f57dfaae6659"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "bb082953-2c91-4649-abc2-f57dfaae6659",
#         "RetryAttempts": 0
#     }
# }
# End of detect_entities

# %%
english_string = 'I study Machine Learning in Seattle on Thursday.'
print('Calling DetectKeyPhrases')
# json.dumps() writes JSON data to a Python string
print(json.dumps(comprehend.detect_entities(Text = english_string, LanguageCode='en'), sort_keys=True, indent=4))
# Out:
# Calling DetectKeyPhrases
# {
#     "Entities": [
#         {
#             "BeginOffset": 8,
#             "EndOffset": 24,
#             "Score": 0.851854145526886,
#             "Text": "Machine Learning",
#             "Type": "OTHER"
#         },
#         {
#             "BeginOffset": 28,
#             "EndOffset": 35,
#             "Score": 0.9999995231628418,
#             "Text": "Seattle",
#             "Type": "LOCATION"
#         },
#         {
#             "BeginOffset": 39,
#             "EndOffset": 47,
#             "Score": 0.9999622106552124,
#             "Text": "Thursday",
#             "Type": "DATE"
#         }
#     ],
#     "ResponseMetadata": {
#         "HTTPHeaders": {
#             "content-length": "303",
#             "content-type": "application/x-amz-json-1.1",
#             "date": "Sat, 18 Jan 2020 05:28:50 GMT",
#             "x-amzn-requestid": "e2a5424b-7115-4ea3-91c9-d19a56358abc"
#         },
#         "HTTPStatusCode": 200,
#         "RequestId": "e2a5424b-7115-4ea3-91c9-d19a56358abc",
#         "RetryAttempts": 0
#     }
# }
